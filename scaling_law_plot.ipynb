# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
def parse(result):
    result_dict = dict()
    for line in result.split('\n'):
        tmp = line.split(' ')
        key = tmp[1][:-1]
        value = float(tmp[2])
        result_dict[key] = value
    return result_dict

def proof_scaling_law_plot(sizes, times):
    plt.plot(sizes, times)
    plt.xlabel('number of parameters')
    plt.ylabel('proof generation time')
    plt.title('Scaling law for proof generation (EZKL)')
    plt.show()

def verify_scaling_law_plot(sizes, times):
    plt.plot(sizes, times)
    plt.xlabel('number of parameters')
    plt.ylabel('verification time')
    plt.title('Scaling law for verification (EZKL)')
    plt.show()

# %% [markdown]
# ## Result upon increase of hidden dimension

# %%
# If you are to change this result for your own plot generation.
# Please do check the formats: they need to be modified a bit (removing plusminus sign, removing single space in ZK AVERAGE ACCURACY)
# for the simplicity of code.
ezkl_hidden_4_result = '''SUM setting_time: 0.20153307914733887
SUM calibration_time: 1.3762178421020508
SUM compile_time: 0.05817461013793945
SUM get_srs_time: 0.07237863540649414
SUM witness_generation_time: 0.8529059886932373
SUM setup_time: 18.259057760238647
SUM proof_generation_time: 30.276396989822388
SUM verification_time: 0.3329010009765625
AVG num_params: 106.0
AVG total: 276.0
AVG correct: 164.0
AVG zk_total: 276.0
AVG zk_correct: 112.0
AVG ACCURACY: 59.42028985507246
ZK AVGACCURACY: 40.57971014492754'''

ezkl_hidden_8_result = '''SUM setting_time: 0.22064590454101562
SUM calibration_time: 1.5242862701416016
SUM compile_time: 0.04524683952331543
SUM get_srs_time: 0.06070971488952637
SUM witness_generation_time: 0.5723345279693604
SUM setup_time: 15.702782392501831
SUM proof_generation_time: 25.067001342773438
SUM verification_time: 0.267794132232666
AVG num_params: 242.0
AVG total: 276.0
AVG correct: 170.0
AVG zk_total: 276.0
AVG zk_correct: 164.0
AVG ACCURACY: 61.59420289855072
ZK AVGACCURACY: 59.42028985507246'''

ezkl_hidden_16_result ='''SUM setting_time: 0.46501851081848145
SUM calibration_time: 3.25538969039917
SUM compile_time: 0.08471488952636719
SUM get_srs_time: 0.0823066234588623
SUM witness_generation_time: 1.120955467224121
SUM setup_time: 32.94321942329407
SUM proof_generation_time: 47.68078374862671
SUM verification_time: 0.46182775497436523
AVG num_params: 610.0
AVG total: 276.0
AVG correct: 199.0
AVG zk_total: 276.0
AVG zk_correct: 164.0
AVG ACCURACY: 72.10144927536231
ZK AVGACCURACY: 59.42028985507246'''

ezkl_hidden_32_result ='''SUM setting_time: 0.6794626712799072
SUM calibration_time: 6.45393180847168
SUM compile_time: 0.09191012382507324
SUM get_srs_time: 0.09331464767456055
SUM witness_generation_time: 1.568361520767212
SUM setup_time: 63.987229347229004
SUM proof_generation_time: 116.36654901504517
SUM verification_time: 0.8473124504089355
AVG num_params: 1730.0
AVG total: 276.0
AVG correct: 185.0
AVG zk_total: 276.0
AVG zk_correct: 98.0
AVG ACCURACY: 67.02898550724638
ZK AVGACCURACY: 35.507246376811594'''

ezkl_hidden_64_result ='''SUM setting_time: 1.172797441482544
SUM calibration_time: 14.894983053207397
SUM compile_time: 0.18106317520141602
SUM get_srs_time: 0.0812540054321289
SUM witness_generation_time: 3.32608699798584
SUM setup_time: 146.64144444465637
SUM proof_generation_time: 257.02196192741394
SUM verification_time: 2.7666938304901123
AVG num_params: 5506.0
AVG total: 276.0
AVG correct: 191.0
AVG zk_total: 276.0
AVG zk_correct: 114.0
AVG ACCURACY: 69.20289855072464
ZK AVGACCURACY: 41.30434782608695'''

ezkl_hidden_128_result = '''SUM setting_time: 2.061863422393799
SUM calibration_time: 33.81355023384094
SUM compile_time: 0.19246268272399902
SUM get_srs_time: 0.06701445579528809
SUM witness_generation_time: 7.66802716255188
SUM setup_time: 374.9613878726959
SUM proof_generation_time: 725.0587906837463
SUM verification_time: 12.360600471496582
AVG num_params: 19202.0
AVG total: 276.0
AVG correct: 161.0
AVG zk_total: 276.0
AVG zk_correct: 146.0
AVG ACCURACY: 58.333333333333336
ZK AVGACCURACY: 52.89855072463768'''

# %%
result_4 = parse(ezkl_hidden_4_result)
result_8 = parse(ezkl_hidden_8_result)
result_16 = parse(ezkl_hidden_16_result)
result_32 = parse(ezkl_hidden_32_result)
result_64 = parse(ezkl_hidden_64_result)
result_128 = parse(ezkl_hidden_128_result)
sizes = []
times = []
for result in [result_4, result_8, result_16, result_32, result_64, result_128]:
    sizes.append(result['num_params'])
    time = result['setting_time'] + result['calibration_time'] + result['compile_time'] + result['get_srs_time'] + result['witness_generation_time'] + result['setup_time'] + result['proof_generation_time']
    times.append(time)

proof_scaling_law_plot(sizes, times)

# %%
sizes = []
times = []
for result in [result_4, result_8, result_16, result_32, result_64, result_128]:
    sizes.append(result['num_params'])
    time = result['verification_time']
    times.append(time)
verify_scaling_law_plot(sizes, times)

# %%
# If you are to change this result for your own plot generation.
# Please do check the formats: they need to be modified a bit (removing plusminus sign, removing single space in ZK AVERAGE ACCURACY)
# for the simplicity of code.
circom_hidden_4_result = '''SUM witness_generation_time: 4.14693284034729
SUM proof_generation_time: 100.47211909294128
SUM verification_time: 13.150549173355103
AVG num_params: 106.0
AVG total: 276.0
AVG correct: 164.0
AVG zk_total: 276.0
AVG zk_correct: 164.0
AVG ACCURACY: 59.42028985507246
ZK AVGACCURACY: 59.42028985507246'''

circom_hidden_8_result = '''SUM witness_generation_time: 5.568607568740845
SUM proof_generation_time: 170.9724578857422
SUM verification_time: 12.25812029838562
AVG num_params: 242.0
AVG total: 276.0
AVG correct: 170.0
AVG zk_total: 276.0
AVG zk_correct: 170.0
AVG ACCURACY: 61.59420289855072
ZK AVGACCURACY: 61.59420289855072'''

circom_hidden_16_result ='''SUM witness_generation_time: 9.420667171478271
SUM proof_generation_time: 344.0056571960449
SUM verification_time: 13.124080419540405
AVG num_params: 610.0
AVG total: 276.0
AVG correct: 199.0
AVG zk_total: 276.0
AVG zk_correct: 199.0
AVG ACCURACY: 72.10144927536231
ZK AVGACCURACY: 72.10144927536231'''

# %%
result_4 = parse(circom_hidden_4_result)
result_8 = parse(circom_hidden_8_result)
result_16 = parse(circom_hidden_16_result)
sizes = []
times = []
for result in [result_4, result_8, result_16]:
    sizes.append(result['num_params'])
    time = result['witness_generation_time'] + result['proof_generation_time']
    times.append(time)

proof_scaling_law_plot(sizes, times)

# %%
sizes = []
times = []
for result in [result_4, result_8, result_16]:
    sizes.append(result['num_params'])
    time = result['verification_time']
    times.append(time)
verify_scaling_law_plot(sizes, times)

# %% [markdown]
# ## Result upon increase of hidden layer

# %%
# If you are to change this result for your own plot generation.
# Please do check the formats: they need to be modified a bit (removing plusminus sign, removing single space in ZK AVERAGE ACCURACY)
# for the simplicity of code.
ezkl_layer_3_result = '''SUM setting_time: 0.20153307914733887
SUM calibration_time: 1.3762178421020508
SUM compile_time: 0.05817461013793945
SUM get_srs_time: 0.07237863540649414
SUM witness_generation_time: 0.8529059886932373
SUM setup_time: 18.259057760238647
SUM proof_generation_time: 30.276396989822388
SUM verification_time: 0.3329010009765625
AVG num_params: 106.0
AVG total: 276.0
AVG correct: 164.0
AVG zk_total: 276.0
AVG zk_correct: 112.0
AVG ACCURACY: 59.42028985507246
ZK AVGACCURACY: 40.57971014492754'''

ezkl_layer_4_result = '''SUM setting_time: 0.27966880798339844
SUM calibration_time: 1.3315401077270508
SUM compile_time: 0.058088064193725586
SUM get_srs_time: 0.06659650802612305
SUM witness_generation_time: 0.6056997776031494
SUM setup_time: 18.03549861907959
SUM proof_generation_time: 26.953876733779907
SUM verification_time: 0.255847692489624
AVG num_params: 126.0±0.0
AVG total: 276.0±0.0
AVG correct: 164.0±0.0
AVG zk_total: 276.0±0.0
AVG zk_correct: 112.0±0.0
AVG ACCURACY: 59.42028985507246
ZK AVG ACCURACY: 40.57971014492754'''

ezkl_layer_5_result ='''SUM setting_time: 0.5795655250549316
SUM calibration_time: 3.8001692295074463
SUM compile_time: 0.2039015293121338
SUM get_srs_time: 0.0872800350189209
SUM witness_generation_time: 1.0523278713226318
SUM setup_time: 31.619330644607544
SUM proof_generation_time: 43.982929706573486
SUM verification_time: 0.501763105392456
AVG num_params: 146.0±0.0
AVG total: 276.0±0.0
AVG correct: 180.0±0.0
AVG zk_total: 276.0±0.0
AVG zk_correct: 112.0±0.0
AVG ACCURACY: 65.21739130434783
ZK AVG ACCURACY: 40.57971014492754'''

ezkl_layer_6_result = '''SUM setting_time: 0.6745002269744873
SUM calibration_time: 3.558302164077759
SUM compile_time: 0.07746243476867676
SUM get_srs_time: 0.07743430137634277
SUM witness_generation_time: 0.7168643474578857
SUM setup_time: 32.01917600631714
SUM proof_generation_time: 71.2849771976471
SUM verification_time: 0.6682558059692383
AVG num_params: 166.0±0.0
AVG total: 276.0±0.0
AVG correct: 162.0±0.0
AVG zk_total: 276.0±0.0
AVG zk_correct: 162.0±0.0
AVG ACCURACY: 58.69565217391305
ZK AVG ACCURACY: 58.69565217391305'''

ezkl_layer_7_result = '''SUM setting_time: 0.7835772037506104
SUM calibration_time: 6.088286399841309
SUM compile_time: 0.2273564338684082
SUM get_srs_time: 0.07577657699584961
SUM witness_generation_time: 0.8273012638092041
SUM setup_time: 115.24143838882446
SUM proof_generation_time: 826.1056649684906
SUM verification_time: 4.212156295776367
AVG num_params: 186.0±0.0
AVG total: 276.0±0.0
AVG correct: 164.0±0.0
AVG zk_total: 276.0±0.0
AVG zk_correct: 164.0±0.0
AVG ACCURACY: 59.42028985507246
ZK AVG ACCURACY: 59.42028985507246'''
